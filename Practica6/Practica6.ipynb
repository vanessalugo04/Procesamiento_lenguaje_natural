# %% [markdown]
# # Práctica 6

# %% [markdown]
# ## Cargar 10 documentos

# %% [markdown]
# Se generaron 10 documentos de los siguientes temas: matemáticas, geografía, biología, turismo y cocina

# %%
#función para leer pdf, solo mandenla llamar :)
from pypdf import PdfReader

def extraer_texto_pdf(ruta_archivo):
    texto_completo = ""

    try:
        reader = PdfReader(ruta_archivo)

        for pagina in reader.pages:
            texto_extraido = pagina.extract_text()
            if texto_extraido:
                texto_completo += texto_extraido + "\n"

        return texto_completo

    except FileNotFoundError:
        return f"Error: No se encontró el archivo '{ruta_archivo}'"
    except Exception as e:
        return f"Ocurrió un error al leer el PDF: {e}"

# %%
turismo1 = extraer_texto_pdf("turismo_patrimonio_cultural.pdf")
turismo2 = extraer_texto_pdf('turismo_sostenible.pdf')
print(f'1.{turismo1[:200]} \n')
print(f'2.{turismo2[:200]}')
# Out:
# 1.Patrimonio Cultural y Turismo: Entre la
#  Conservación y el Acceso
# El concepto de patrimonio cultural
# El patrimonio cultural de una sociedad está constituido por el conjunto de bienes
# materiales e inma
#
# 2.Turismo Sostenible: Principios y Prácticas para un
#  Viaje Responsable
# ¿Qué es el turismo sostenible?
# El turismo sostenible es aquel que satisface las necesidades de los turistas actuales y de
# las comu

# %%
mate1 = extraer_texto_pdf("matematicas_calculo_diferencial.pdf")
mate2 = extraer_texto_pdf('matematicas_estadistica_descriptiva.pdf')
print(f'1.{mate1[:200]} \n')
print(f'2.{mate2[:200]}')
# Out:
# 1.Introducción al Cálculo Diferencial
# ¿Qué es el cálculo diferencial?
# El cálculo diferencial es una rama de las matemáticas que estudia cómo cambian las
# funciones. Su objeto central es la derivada, un c
#
# 2.Estadística Descriptiva: Fundamentos y Métodos
# Introducción a la estadística descriptiva
# La estadística descriptiva es la rama de la estadística dedicada a recopilar, organizar,
# resumir y presentar da

# %%
geo1 = extraer_texto_pdf("geografia_cambio_climatico.pdf")
geo2 = extraer_texto_pdf('geografia_urbanizacion.pdf')
print(f'1.{geo1[:200]} \n' )
print(f'2.{geo2[:200]}')
# Out:
# 1.Cambio Climático: Causas, Efectos y Perspectivas
#  Geográficas
# El sistema climático terrestre
# El clima de la Tierra es el resultado de complejas interacciones entre la atmósfera, la
# hidrosfera, la crio
#
# 2.Urbanización Mundial: Procesos, Retos y
#  Transformaciones
# El fenómeno de la urbanización
# La urbanización es uno de los procesos geográficos más significativos de la historia
# moderna. Se define como el

# %%
bio1 = extraer_texto_pdf("biologia_ecosistemas.pdf")
bio2 = extraer_texto_pdf('biologia_la_celula.pdf')
print(f'1.{bio1[:200]} \n')
print(f'2.{bio2[:200]}')
# Out:
# 1.Ecosistemas: Estructura, Función y Biodiversidad
# ¿Qué es un ecosistema?
# Un ecosistema es un sistema complejo formado por todos los organismos vivos que
# habitan en un área determinada —la comunidad bió
#
# 2.La Célula: Unidad Fundamental de la Vida
# Historia del descubrimiento celular
# La historia de la biología celular comienza en el siglo XVII con la invención del
# microscopio. En 1665, el científico inglé

# %%
cocina1 = extraer_texto_pdf('cocina_gastronomia_molecular.pdf')
cocina2 = extraer_texto_pdf('cocina_gastronomias_del_mundo.pdf')
print(f'1.{cocina1[:200]} \n')
print(f'2.{cocina2[:200]}')
# Out:
# 1.Gastronomía Molecular: Ciencia en la Cocina
# Orígenes de la cocina molecular
# La gastronomía molecular es una disciplina que aplica los principios y técnicas de la
# química y la física para transformar l
#
# 2.Gastronomías del Mundo: Un Viaje Culinario por
#  los Cinco Continentes
# La cocina como espejo de la cultura
# La gastronomía de un pueblo es mucho más que un conjunto de recetas: es un reflejo de
# su histo

# %% [markdown]
# ## Preprocesamiento

# %% [markdown]
# ### Contador de palabras

# %%
def contador_palabras(texto):

    contador = 0
    en_palabra = False

    for caracter in texto:

        if caracter != " " and caracter != "\n" and caracter != "\t":

            if not en_palabra:
                contador += 1
                en_palabra = True

        else:
            en_palabra = False

    return contador

# %% [markdown]
# ### StopWords

# %%
stopwords_turismo = ([
    'de','la','que','el','en','y','a','los','del','se','las','por','un','para','con','no','una',
    'su','al','lo','como','más','pero','sus','le','ya','o','este','sí','porque','esta','entre',
    'cuando','muy','sin','sobre','también','me','hasta','hay','donde','quien','desde','todo',
    'nos','durante','todos','uno','les','ni','tú','tus','te','ti','tu','vos','vosotros',
    'vosotras','ustedes','ello','ellos','ellas','mío','mía','míos','mías',
    'tuyo','tuya','tuyos','tuyas','suyo','suya','suyos','suyas','nuestro','nuestra',
    'nuestros','nuestras',
    'es','son','ser','fue','fueron','puede','pueden','ha','han','como','dado','si','ya','entre',
    'tambien','asi','aunque','cada','este','esta','estos','estas','ese','esa','eso',
    'hay','tener','tiene','tienen','hacer','hace','hacer','hacerlo','forma','manera',
    'parte','partes','ejemplo','ejemplos','caso','casos','importante','gran','mayor',
    'relacion','relaciones','uso','usos','valor','valores'
])

# %%
stopwords_matematicas = ([
    'de','la','que','el','en','y','a','los','del','se','las','por','un','para','con','no','una',
    'su','al','lo','como','más','pero','sus','le','ya','o','este','sí','porque','esta','entre',
    'cuando','muy','sin','sobre','también','me','hasta','hay','donde','quien','desde','todo',
    'nos','durante','todos','uno','les','ni','tú','tus','te','ti','tu','vos','vosotros',
    'vosotras','ustedes','ello','ellos','ellas','nuestro','nuestra','nuestros','nuestras',
    'es','son','ser','fue','fueron','puede','pueden','ha','han','tener','tiene','tienen',
    'hacer','hace','hacerlo','usar','utiliza','utilizan','permite','permiten',
    'forma','manera','tipo','tipos','parte','partes','ejemplo','ejemplos',
    'caso','casos','nivel','medio','general','principal','importante',
    'mayor','menor','nuevo','nueva','nuevos','nuevas', 'proceso','sistema','sistemas',
    'modelo','modelos','conjunto','conjuntos','elemento','elementos',
    'diferente','diferentes','mismo','misma','mismos','mismas',
    'asi','aunque','cada','si','ya','tambien','entre'
])

# %%
stopwords_biologia = ([
    'de','la','que','el','en','y','a','los','del','se','las','por','un','para','con','no','una',
    'su','al','lo','como','más','pero','sus','le','ya','o','este','sí','porque','esta','entre',
    'cuando','muy','sin','sobre','también','me','hasta','hay','donde','quien','desde','todo',
    'nos','durante','todos','uno','les','ni','tú','te','ti','tu','vos','ustedes','ello','ellos',
    'ellas','mío','mía','míos','mías','tuyo','tuya','tuyos','tuyas','suyo','suya','suyos','suyas',
    'nuestro','nuestra','nuestros','nuestras','al','del','pues','es','son','ser','fue','fueron',
    'puede','pueden','dado','así','bien','solo','cada','otro','otra','otros','otras','mismo',
    'misma','mismos','mismas','tanto','tanta','tantos','tantas','mediante','dicho','dichas',
    'siendo','hacia','parte','través','forma','tipo','tipos','hace','hacer','tiene','tienen',
    'gran','sino','aún','aquí','allí','entonces','luego','aunque','embargo','además','incluso', 
    'especie','especies','población','poblaciones',
    'comunidad','comunidades','energía','materia','natural','naturales','vida','vivo','vivos',
    'tipo','forma','formas','través','parte'
])

# %%
stopwords_geografia = ([
    'de','la','que','el','en','y','a','los','del','se','las','por','un','para','con','no','una',
    'su','al','lo','como','más','pero','sus','le','ya','o','este','sí','porque','esta','entre',
    'cuando','muy','sin','sobre','también','me','hasta','hay','donde','quien','desde','todo',
    'nos','durante','todos','uno','les','ni','tú','te','ti','tu','vos','ustedes','ello','ellos',
    'ellas','mío','mía','míos','mías','tuyo','tuya','tuyos','tuyas','suyo','suya','suyos','suyas',
    'nuestro','nuestra','nuestros','nuestras','al','del','pues','es','son','ser','fue','fueron',
    'puede','pueden','dado','así','bien','solo','cada','otro','otra','otros','otras','mismo',
    'misma','mismos','mismas','tanto','tanta','tantos','tantas','mediante','dicho','dichas',
    'siendo','hacia','parte','través','forma','tipo','tipos','hace','hacer','tiene','tienen',
    'gran','sino','aún','aquí','allí','entonces','luego','aunque','embargo','además','incluso',
    'área','áreas','zona','zonas','región','regiones','espacio','espacios','territorio',
    'mundo','mundial','país','países',
    'planeta','superficie','proceso','procesos','sistema','sistemas','desarrollo'
])

# %%
stopwords_cocina = ([
    'de','la','que','el','en','y','a','los','del','se','las','por','un','para','con','no','una',
    'su','al','lo','como','más','pero','sus','le','ya','o','este','sí','porque','esta','entre',
    'cuando','muy','sin','sobre','también','me','hasta','hay','donde','quien','desde','todo',
    'nos','durante','todos','uno','les','ni','tú','te','ti','tu','vos','ustedes','ello','ellos',
    'ellas','mío','mía','míos','mías','tuyo','tuya','tuyos','tuyas','suyo','suya','suyos','suyas',
    'nuestro','nuestra','nuestros','nuestras','al','del','pues','es','son','ser','fue','fueron',
    'puede','pueden','dado','así','bien','solo','cada','otro','otra','otros','otras','mismo',
    'misma','mismos','mismas','tanto','tanta','tantos','tantas','mediante','dicho','dichas',
    'siendo','hacia','parte','través','forma','tipo','tipos','hace','hacer','tiene','tienen',
    'gran','sino','aún','aquí','allí','entonces','luego','aunque','embargo','además','incluso',
    'técnica','técnicas', 'preparación','preparaciones','sabor','sabores','textura','texturas',
    'temperatura','temperaturas', 'tradicional','tradicionales',
    'mundo','mundial','uso','usos','proceso','procesos'
])

# %% [markdown]
# ### Convertir a Minusculas

# %%
def to_minusculas(texto):

    letras = ""

    for letra in texto:

        if ord(letra) >= 65 and ord(letra) <= 90:
            nueva_letra = chr(ord(letra) + 32)
            letras += nueva_letra

        else:
            letras += letra

    return letras

# %% [markdown]
# ### Tokenizar

# %%
def es_valido(caracter):
  c = ord(caracter)
    # minusculas y mayusculas
  if (c >= 97 and c <= 122) or (c >= 65 and c <= 90):
    return True
    #
  if ((c == 225) or (c == 233) or (c == 327) or (c == 243) or (c == 250) or (c == 241)):#unicode
    return True
    # minusculas con acento
  if c == 160 or c == 130 or c == 161 or c == 162 or c == 163:
    return True
    # mayusculas con acento
  if c == 181 or c == 144 or c == 214 or c == 224 or c == 233:
    return True
  else:
    return False

# %%
def tokenizador(texto, stopwords, valido):
    token = ""
    tokens = [None] * len(texto)
    j = 0

    for i in range(len(texto)):
        if valido(texto[i]):
            token += texto[i]
        else:
            if token != "":
                if token not in stopwords:
                    tokens[j] = token
                    j += 1
                token = ''

    return tokens[0:j]

# %%
def contar_tokens(lista_tokens):
    contador = 0
    for elemento in lista_tokens:
        contador += 1
    return contador

# %% [markdown]
# ### Lematización

# %%
#sufijo → terminación de infinitivo
REGLAS_VERBOS = [
    #ar
    ('aremos', 'ar'), ('aréis', 'ar'), ('arán', 'ar'),
    ('aré',   'ar'), ('arás',  'ar'), ('ará',  'ar'),
    #er
    ('eremos', 'er'), ('eréis', 'er'), ('erán', 'er'),
    ('eré',   'er'), ('erás',  'er'), ('erá',  'er'),
    #ir
    ('iremos', 'ir'), ('iréis', 'ir'), ('irán', 'ir'),
    ('iré',   'ir'), ('irás',  'ir'), ('irá',  'ir'),

    ('asteis', 'ar'), ('aste',  'ar'), ('aron', 'ar'),
    ('isteis', 'ir'), ('iste',  'ir'), ('ieron','ir'),
    ('imos',   'ir'),

    ('ábamos', 'ar'), ('abais', 'ar'), ('aban', 'ar'),
    ('aba',    'ar'), ('abas',  'ar'),
    ('íamos',  'er'), ('íais',  'er'), ('ían',  'er'),

    # participios
    ('ados',  'ar'), ('adas',  'ar'), ('ado',  'ar'), ('ada',  'ar'),
    ('idos',  'ir'), ('idas',  'ir'), ('ido',  'ir'), ('ida',  'ir'),

    # gerundio
    ('ando',  'ar'),
    ('iendo', 'er'),

    ('áis',   'ar'), ('éis',   'er'), ('ís',    'ir'),
]

# %%
#  forma conjugada / plural / adverbio → lema
EXCEPCIONES = {
    # ser
    'soy':'ser','eres':'ser','es':'ser','somos':'ser',
    'sois':'ser','son':'ser','era':'ser','eras':'ser',
    'éramos':'ser','erais':'ser','eran':'ser',
    'fui':'ser','fuiste':'ser','fue':'ser',
    'fuimos':'ser','fuisteis':'ser','fueron':'ser',
    'seré':'ser','serás':'ser','será':'ser',
    'seremos':'ser','seréis':'ser','serán':'ser',
    'sido':'ser','siendo':'ser',

    # estar
    'estoy':'estar','estás':'estar','está':'estar',
    'estamos':'estar','estáis':'estar','están':'estar',
    'estaba':'estar','estabas':'estar','estaban':'estar',
    'estuve':'estar','estuvo':'estar','estuvieron':'estar',
    'estará':'estar','estarán':'estar','estado':'estar',

    #haber
    'he':'haber','has':'haber','ha':'haber',
    'hemos':'haber','habéis':'haber','han':'haber',
    'había':'haber','habían':'haber','hubo':'haber',
    'habrá':'haber','habría':'haber','habido':'haber',

    #tener
    'tengo':'tener','tienes':'tener','tiene':'tener',
    'tenemos':'tener','tenéis':'tener','tienen':'tener',
    'tenía':'tener','tenían':'tener','tuve':'tener',
    'tuvo':'tener','tuvieron':'tener','tendrá':'tener',
    'tendrán':'tener','tenido':'tener',

    # ir
    'voy':'ir','vas':'ir','va':'ir',
    'vamos':'ir','vais':'ir','van':'ir',
    'iba':'ir','ibas':'ir','iban':'ir',
    'irá':'ir','irán':'ir','ido':'ir',

    #hacer
    'hago':'hacer','haces':'hacer','hace':'hacer',
    'hacemos':'hacer','hacéis':'hacer','hacen':'hacer',
    'hacía':'hacer','hacían':'hacer','hice':'hacer',
    'hizo':'hacer','hicieron':'hacer','hará':'hacer',
    'harán':'hacer','hecho':'hacer',

    # poder
    'puedo':'poder','puedes':'poder','puede':'poder',
    'podemos':'poder','podéis':'poder','pueden':'poder',
    'podía':'poder','podían':'poder','pudo':'poder',
    'pudieron':'poder','podrá':'poder','podrán':'poder',
    'podido':'poder',

    #decir
    'digo':'decir','dices':'decir','dice':'decir',
    'decimos':'decir','decís':'decir','dicen':'decir',
    'decía':'decir','dijo':'decir','dijeron':'decir',
    'dirá':'decir','dirán':'decir','dicho':'decir',

    #venir
    'vengo':'venir','vienes':'venir','viene':'venir',
    'venimos':'venir','venís':'venir','vienen':'venir',
    'venía':'venir','vino':'venir','vinieron':'venir',
    'vendrá':'venir','vendrán':'venir','venido':'venir',

    # saber
    'sé':'saber','sabes':'saber','sabe':'saber',
    'sabemos':'saber','sabéis':'saber','saben':'saber',
    'sabía':'saber','sabían':'saber','supo':'saber',
    'supieron':'saber','sabrá':'saber','sabrán':'saber',
    'sabido':'saber',

    # ver
    'veo':'ver','ves':'ver','ve':'ver',
    'vemos':'ver','veis':'ver','ven':'ver',
    'veía':'ver','veían':'ver','vio':'ver',
    'vieron':'ver','verá':'ver','verán':'ver',
    'visto':'ver',

    # dar
    'doy':'dar','das':'dar','da':'dar',
    'damos':'dar','dais':'dar','dan':'dar',
    'daba':'dar','daban':'dar','dio':'dar',
    'dieron':'dar','dará':'dar','darán':'dar',
    'dado':'dar',

    #querer
    'quiero':'querer','quieres':'querer','quiere':'querer',
    'queremos':'querer','queréis':'querer','quieren':'querer',
    'quería':'querer','querían':'querer','quiso':'querer',
    'quisieron':'querer','querrá':'querer','querido':'querer',

    # adverbios que terminan en 'mente'
    'rápidamente':'rápido','lentamente':'lento',
    'fácilmente':'fácil','difícilmente':'difícil',
    'claramente':'claro','directamente':'directo',
    'finalmente':'final','actualmente':'actual',
    'principalmente':'principal','especialmente':'especial',
    'generalmente':'general','normalmente':'normal',
    'naturalmente':'natural','socialmente':'social',
    'culturalmente':'cultural','económicamente':'económico',
    'históricamente':'histórico','científicamente':'científico',
    'políticamente':'político','tecnológicamente':'tecnológico',
    'radicalmente':'radical','parcialmente':'parcial',
    'constantemente':'constante','completamente':'completo',
    'significativamente':'significativo','notablemente':'notable',
    'permanentemente':'permanente','abruptamente':'abrupto',
    'aceleradamente':'acelerado','exponencialmente':'exponencial',
    'dramáticamente':'dramático','alarmantemente':'alarmante',

    # plurales irregulares
    'caracteres':'carácter','lápices':'lápiz',
    'raíces':'raíz','países':'país','reyes':'rey',
    'leyes':'ley','voces':'voz','luces':'luz',
    'peces':'pez','jueces':'juez','cruces':'cruz',
    'nueces':'nuez','hombres':'hombre','mujeres':'mujer',
    'análisis':'análisis','síntesis':'síntesis',
    'crisis':'crisis','tesis':'tesis',
    'hipótesis':'hipótesis',

    # sustantivos
    'ciudades':'ciudad','sociedades':'sociedad',
    'civilizaciones':'civilización','naciones':'nación',
    'generaciones':'generación','poblaciones':'población',
    'revoluciones':'revolución','tradiciones':'tradición',
    'temperaturas':'temperatura','emisiones':'emisión',
    'tasas':'tasa','niveles':'nivel','mercados':'mercado',
    'gobiernos':'gobierno','bancos':'banco',
    'sistemas':'sistema','programas':'programa',
    'datos':'dato','algoritmos':'algoritmo',
    'empresas':'empresa','inversiones':'inversión',
    'científicos':'científico','médicos':'médico',
    'estudiantes':'estudiante','profesores':'profesor',
    'universidades':'universidad','instituciones':'institución',
    'habilidades':'habilidad','herramientas':'herramienta',
    'metodologías':'metodología','estrategias':'estrategia',
    'tecnologías':'tecnología','energías':'energía',
    'economías':'economía','predicciones':'predicción',
    'imágenes':'imagen','millones':'millón',
    'billones':'billón','sectores':'sector',
    'modelos':'modelo','servicios':'servicio',
    'clases':'clase','escuelas':'escuela',
    'currículos':'currículo','índices':'índice',
    'enfermedades':'enfermedad','tratamientos':'tratamiento',
    'vacunas':'vacuna','hospitales':'hospital',
    'pacientes':'paciente','investigadores':'investigador',
    'activistas':'activista','combustibles':'combustible',
    'glaciares':'glaciar','ecosistemas':'ecosistema',
    'cadenas':'cadena','criptomonedas':'criptomoneda',
    'inversionistas':'inversionista','trabajadores':'trabajador',
    'máquinas':'máquina','chips':'chip','robots':'robot',
    'asistentes':'asistente','ciudades':'ciudad','sensores':'sensor',

    #xpeciones
    'ofrecieron': 'ofrecer', 'ofrecerá': 'ofrecer', 'ofreció': 'ofrecer',
    'derritieron': 'derretir', 'derritió': 'derretir',
    'alcanzó': 'alcanzar', 'alcanzaron': 'alcanzar',
    'revolucionó': 'revolucionar',
    'infectó': 'infectar', 'convirtió': 'convertir',
    'deterioró': 'deteriorar', 'motivó': 'motivar',
    'amplió': 'ampliar', 'destruyó': 'destruir',
    'firmaron': 'firmar', 'invirtieron': 'invertir',
    'incorporaron': 'incorporar', 'identificaron': 'identificar',
    'diseñaron': 'diseñar', 'participaron': 'participar',
    'colapsaron': 'colapsar', 'descubrieron': 'descubrir',
    'implementaron': 'implementar', 'atrajeron': 'atraer',

    #más excepciones
    'últimos': 'último', 'últimas': 'última',
    'décadas': 'década', 'dióxido': 'dióxido',
    'celsius': 'celsius', 'hardware': 'hardware',
    'internet': 'internet', 'streaming': 'streaming',
}

# %%
# para plurales/femeninos genéricos
REGLAS_MORFOLOGICAS = [
    ('idades', 'idad'),
    ('iciones', 'ición'),
    ('ciones', 'ción'),
    ('iones',  'ión'),
    ('ades',   'ad'),
    ('eces',   'ez'),
    ('ores',   'or'),
    ('eres',   'er'),
    ('ales',   'al'),
    ('ajes',   'aje'),
    ('istas',  'ista'),
    ('entes',  'ente'),
    ('antes',  'ante'),
    ('icos',   'ico'),
    ('icas',   'ica'),
    ('ivos',   'ivo'),
    ('ivas',   'iva'),
    ('bles',   'ble'),
    ('les',    'l'),
    ('as',     'a'),
    ('os',     'o'),
    ('es',     ''),
    ('s',      ''),
]

# %%
def longitud(palabra):
    cantidad_caracteres = 0
    for caracter in palabra:
        cantidad_caracteres = cantidad_caracteres + 1
    return cantidad_caracteres


def termina_en(palabra, sufijo):
    long_p = longitud(palabra)
    long_s = longitud(sufijo)
    if long_s > long_p:
        return False
    return palabra[long_p - long_s:] == sufijo


def lematizador(texto):
    texto_lematizado = [None] *len(texto) #acumulador del texto
    j = 0 #contador de palabras
    palabra_actual = '' #acumulador por palabra
    
    texto_procesar = texto + ' '

    for caracter in texto_procesar:
        if caracter != " " and caracter != "\n" and caracter != "\t":
            palabra_actual += caracter #se va armando la palabra
            
        else: #si hay salto de linea se termina de armar la palabra y se procesa
            if longitud(palabra_actual) > 0: #esto evita procesar muchos espacios en blanco xd
                palabra_lematizada = None 
                
                for sufijo, terminacion in REGLAS_VERBOS:
                    if longitud(palabra_actual) - longitud(sufijo) >= 3 and termina_en(palabra_actual, sufijo):
                        palabra_lematizada = palabra_actual[:-longitud(sufijo)] + terminacion
                        break

                if palabra_lematizada is None:
                    if palabra_actual in EXCEPCIONES:
                        palabra_lematizada = EXCEPCIONES[palabra_actual]
                    else:
                        for sufijo, reemplazo in REGLAS_MORFOLOGICAS:
                            min_raiz = 4 if sufijo in ('eres', 'es', 's') else 3
                            if longitud(palabra_actual) - longitud(sufijo) >= min_raiz and termina_en(palabra_actual, sufijo):
                                palabra_lematizada = palabra_actual[:-longitud(sufijo)] + reemplazo
                                break

                        if palabra_lematizada is None: #si la palabra vacia no esta lematizada
                            palabra_lematizada = palabra_actual #la pasa tal cual

                texto_lematizado[j] = palabra_lematizada
                j = j + 1
                palabra_actual = ''
    
    return texto_lematizado[:j]

# %%
def lematizador_tokenizado(documento_tokenizado):
    texto_lematizado = [None] * len(documento_tokenizado) 
    j = 0 
    
    for palabra in documento_tokenizado:
        palabra_lematizada = None
        
        for sufijo, terminacion in REGLAS_VERBOS:
            if longitud(palabra) - longitud(sufijo) >= 3 and termina_en(palabra, sufijo):
                palabra_lematizada = palabra[:-longitud(sufijo)] + terminacion
                break

        if palabra_lematizada is None:
            if palabra in EXCEPCIONES:
                palabra_lematizada = EXCEPCIONES[palabra]
            else:
                for sufijo, reemplazo in REGLAS_MORFOLOGICAS:
                    min_raiz = 4 if sufijo in ('eres', 'es', 's') else 3
                    if longitud(palabra) - longitud(sufijo) >= min_raiz and termina_en(palabra, sufijo):
                        palabra_lematizada = palabra[:-longitud(sufijo)] + reemplazo
                        break

                if palabra_lematizada is None:
                    palabra_lematizada = palabra

        texto_lematizado[j] = palabra_lematizada
        j = j + 1
        
    return texto_lematizado

# %% [markdown]
# ### IMPLEMENTANCION

# %% [markdown]
# Total de palabras sin preprocesar por cada documento

# %%
print(f'Total de Palabras Documento Tursimo1: {contador_palabras(turismo1)}')
print(f'Total de Palabras Documento Tursimo2: {contador_palabras(turismo2)}')
print(f'Total de Palabras Documento Matematicas1: {contador_palabras(mate1)}')
print(f'Total de Palabras Documento Matematicas2: {contador_palabras(mate2)}')
print(f'Total de Palabras Documento Geografia1: {contador_palabras(geo1)}')
print(f'Total de Palabras Documento Geografia2: {contador_palabras(geo2)}')
print(f'Total de Palabras Documento Biologia1: {contador_palabras(bio1)}')
print(f'Total de Palabras Documento Biologia2: {contador_palabras(bio2)}')
print(f'Total de Palabras Documento Cocina1: {contador_palabras(cocina1)}')
print(f'Total de Palabras Documento Cocina2: {contador_palabras(cocina2)}')
# Out:
# Total de Palabras Documento Tursimo1: 825
# Total de Palabras Documento Tursimo2: 771
# Total de Palabras Documento Matematicas1: 734
# Total de Palabras Documento Matematicas2: 695
# Total de Palabras Documento Geografia1: 807
# Total de Palabras Documento Geografia2: 796
# Total de Palabras Documento Biologia1: 835
# Total de Palabras Documento Biologia2: 813
# Total de Palabras Documento Cocina1: 889
# Total de Palabras Documento Cocina2: 884

# %% [markdown]
# Aplicamos funciones de mayusucula a minuscula y tokenizamos

# %%
corpus_turismo1_tokenizado = tokenizador(to_minusculas(turismo1), stopwords_turismo, es_valido)
corpus_turismo2_tokenizado = tokenizador(to_minusculas(turismo2), stopwords_turismo, es_valido)

corpus_mate1_tokenizado = tokenizador(to_minusculas(mate1), stopwords_matematicas, es_valido)
corpus_mate2_tokenizado = tokenizador(to_minusculas(mate2), stopwords_matematicas, es_valido)

corpus_bio1_tokenizado = tokenizador(to_minusculas(bio1), stopwords_biologia, es_valido)
corpus_bio2_tokenizado = tokenizador(to_minusculas(bio2), stopwords_biologia, es_valido)

corpus_geo1_tokenizado = tokenizador(to_minusculas(geo1), stopwords_geografia, es_valido)
corpus_geo2_tokenizado = tokenizador(to_minusculas(geo2), stopwords_geografia, es_valido)

corpus_cocina1_tokenizado = tokenizador(to_minusculas(cocina1), stopwords_cocina, es_valido)
corpus_cocina2_tokenizado = tokenizador(to_minusculas(cocina2), stopwords_cocina, es_valido)


# imprimimos los primeros 50
print(f"\n Tokens Turismo1 \n {corpus_turismo1_tokenizado}")
print(f"\n Tokens Turismo2 \n {corpus_turismo2_tokenizado}")
print(f"\n Tokens Matemeaticas1 \n {corpus_mate1_tokenizado}")
print(f"\n Tokens Matematicas2 \n {corpus_mate2_tokenizado}")
print(f"\n Tokens Biologia1 \n {corpus_bio1_tokenizado}")
print(f"\n Tokens Biologia2 \n {corpus_bio2_tokenizado}")
print(f"\n Tokens Geografia1 \n {corpus_geo1_tokenizado}")
print(f"\n Tokens Geografia2 \n {corpus_geo2_tokenizado}")
print(f"\n Tokens Cocina1 \n {corpus_cocina1_tokenizado}")
print(f"\n Tokens Cocina2 \n {corpus_cocina2_tokenizado}")
# Out:
#  Tokens Turismo1
está', 'cerrada', 'público', 'solo', 'permite', 'entrada', 'pequeño', 'número', 'investigadores', 'turistas', 'visitan', 'reproducción', 'exacta', 'turismo', 'oscuro', 'dark', 'tourism', 'modalidad', 'fascinante', 'controvertida', 'turismo', 'cultural', 'llamado', 'turismo', 'oscuro', 'dark', 'tourism', 'visita', 'lugares', 'asociados', 'muerte', 'sufrimiento', 'tragedia', 'horror', 'campos', 'concentración', 'auschwitz', 'birkenau', 'polonia', 'memorial', 's', 'nueva', 'york', 'campos', 'muerte', 'camboya', 'sitios', 'atentados', 'madrid', 'destinos', 'turismo', 'oscuro', 'atraen', 'millones', 'visitantes', 'año', 'defensores', 'tipo', 'turismo', 'argumentan', 'profundo', 'educativo', 'conmemorativo', 'visitar', 'auschwitz', 'confrontar', 'realidad', 'holocausto', 'experiencia', 'ningún', 'libro', 'reemplazar', 'cr', 'ticos', 'cambio', 'preguntan', 'transformación' ...
#
#  Tokens Turismo2
#  ['turismo', 'sostenible', 'principios', 'prácticas', 'viaje', 'responsable', 'qué', 'turismo', 'sostenible', 'turismo', 'sostenible', 'aquel', 'satisface', 'necesidades', 'turistas', 'actuales', 'comunidades', 'receptoras', 'protegiendo', 'mejorando', 'oportunidades', 'futuro', 'basa', 'tres', 'pilares', 'fundamentales', 'sostenibilidad', 'ambiental', 'sostenibilidad', 'sociocultural', 'sostenibilidad', 'económica', 'organización', 'mundial', 'turismo', 'omt', 'define', 'turismo', 'plenamente', 'cuenta', 'repercusiones', 'actuales', 'futuras', 'económicas', 'sociales', 'medioambientales', 'satisfacer', 'necesidades', 'visitantes', 'industria', 'entorno', 'comunidades', 'anfitrionas', 'turismo', 'industrias', 'grandes', 'mundo', 'antes', 'pandemia', 'covid', 'generaba', 'aproximadamente', 'pib', 'mundial', 'empleaba', 'diez', 'trabajadores', 'embargo', 'genera', 'impactos', 'negativos', 'significativos', 'contaminación', 'sobreexplotación', 'recursos', 'naturales', 'degradación', 'sitios', 'patrimoniales', 'alteración', 'culturas', 'locales', 'emisiones', 'carbono', 'turismo', 'sostenible', 'busca', 'maximizar', 'beneficios', 'minimizar', 'esos', 'impactos', 'impacto', 'ambiental', 'turismo', 'transporte', 'aéreo', 'fuente', 'emisiones', 'significativa', 'sector', 'tur', 'stico', 'vuelo', 'ida', 'vuelta', 'madrid', 'nueva', 'york', 'genera', 'aproximadamente', 'tonelada', 'co', 'pasajero', 'equivale', 'varios', 'meses', 'conducción', 'automóvil', 'convencional', 'además', 'transporte', 'construcción', 'operación', 'hoteles', 'consume', 'grandes', 'cantidades', 'agua', 'energ', 'genera', 'residuos', 'contaminar', 'ecosistemas', 'frágiles', 'gestionan', 'correctamente', 'turismo', 'masas', 'llevado', 'fenómeno', 'overtourism', 'destinos', 'venecia', 'dubrovnik', 'playas', 'tailandia', 'templos', 'angkor', 'wat', 'afluencia', 'masiva', 'degrada', 'ecosistemas', 'daña', 'patrimonio', 'arquitectónico', 'reduce', 'calidad', 'vida', 'residentes', 'locales', 'ciudades', 'msterdam', 'barcelona', 'florencia', 'implementado', 'medidas', 'limitar', 'turismo', 'masivo', 'redistribuirlo', 'hacia', 'zonas', 'menos', 'saturadas', 'dimensión', 'sociocultural', 'turismo', 'responsable', 'turismo', 'fuerza', 'poderosa', 'preservación', 'cultural', 'contrario', 'agente', 'degradación', 'homogeneización', 'gestiona', 'bien', 'genera', 'ingresos', 'incentivan', 'conservación', 'tradiciones', 'artesan', 'as', 'gastronom', 'local', 'e', 'idiomas', 'riesgo', 'desaparición', 'contacto', 'otras', 'culturas', 'fomentar', 'comprensión', 'respeto', 'mutuo', 'embargo', 'turismo', 'mal', 'planificado', 'convertir', 'cultura', 'local', 'espectáculo', 'folklórico', 'superficial', 'mercantilizar', 'tradiciones', 'respeto', 'comunidades', 'locales', 'implica', 'pedir', 'permiso', 'antes', 'fotografiar', 'personas', 'cumplir', 'códigos', 'vestimenta', 'sitios', 'religiosos', 'aprender', 'algunas', 'palabras', 'idioma', 'local', 'evitar', 'comportamientos', 'residentes', 'consideran', 'irrespetuosos', 'viajeros', 'responsables', 'informan', 'historia', 'cultura', 'destino', 'antes', 'viajar', 'procuran', 'relacionarse', 'comunidad', 'auténtica', 'meros', 'consumidores', 'experiencias', 'ecoturismo', 'turismo', 'comunitario', 'ecoturismo', 'modalidad', 'turismo', 'sostenible', 'orientada', 'hacia', 'espacios', 'naturales', 'busca', 'contribuir', 'conservación', 'involucrar', 'comunidades', 'locales', 'gestión', 'educar', 'visitantes', 'biodiversidad', 'costa', 'rica', 'considerada', 'pionera', 'mundial', 'ecoturismo', 'logrado', 'combinar', 'protección', 'bosques', 'tropicales', 'desarrollo', 'económico', 'comunidades', 'rurales', 'través', 'turismo', 'naturaleza', 'turismo', 'comunitario', 'va', 'paso', 'allá', 'pone', 'comunidades', 'locales', 'centro', 'actividad', 'tur', 'stica', 'propietarias', 'gestoras', 'servicios', 'visitantes', 'alojan', 'casas', 'familiares', 'consumen', 'alimentos', 'producidos', 'localmente', 'participan', 'actividades', 'cotidianas',  ...
#
#  Tokens Matemeaticas1
#  ['introducción', 'cálculo', 'diferencial', 'qué', 'cálculo', 'diferencial', 'cálculo', 'diferencial', 'rama', 'matemáticas', 'estudia', 'cómo', 'cambian', 'funciones', 'objeto', 'central', 'derivada', 'concepto', 'medir', 'tasa', 'variación', 'instantánea', 'cantidad', 'respecto', 'otra', 'desarrollado', 'independiente', 'isaac', 'newton', 'gottfried', 'wilhelm', 'leibniz', 'siglo', 'xvii', 'cálculo', 'diferencial', 'transformó', 'humanidad', 'comprende', 'movimiento', 'cambio', 'relaciones', 'magnitudes', 'variables', 'antes', 'existiera', 'cálculo', 'matemáticos', 'trabajaban', 'geometr', 'estática', 'álgebra', 'hab', 'herramientas', 'formales', 'describir', 'velocidad', 'objeto', 'instante', 'preciso', 'pendiente', 'curva', 'punto', 'espec', 'fico', 'intuición', 'pod', 'acercar', 'segmento', 'curva', 'aproximar', 'tangente', 'exist', 'griegos', 'newton', 'leibniz', 'quienes', 'formalizaron', 'esa', 'idea', 'mediante', 'concepto', 'l', 'mite', 'concepto', 'l', 'mite', 'l', 'mite', 'piedra', 'angular', 'cálculo', 'decimos', 'l', 'mite', 'función', 'f', 'x', 'x', 'tiende', 'valor', 'l', 'medida', 'x', 'acerca', 'f', 'x', 'acerca', 'l', 'idea', 'aparentemente', 'sencilla', 'tardó', 'siglos', 'recibir', 'definición', 'rigurosa', 'matemático', 'augustin', 'louis', 'cauchy', 'siglo', 'xix', 'estableció', 'definición', 'épsilon', 'delta', 'enseña', 'hoy', 'universidades', 'l', 'mites', 'resolver', 'situaciones', 'expresión', 'matemática', 'resulta', 'indeterminada', 'punto', 'concreto', 'expresión', 'x', 'x', 'está', 'definida', 'x', 'provoca', 'división', 'cero', 'embargo', 'factorizar', 'numerador', 'simplificar', 'obtiene', 'l', 'mite', 'x', 'tiende', 'igual', 'análisis', 'fundamental', 'definir', 'derivada', 'derivada', 'interpretación', 'geométrica', 'derivada', 'función', 'f', 'punto', 'x', 'define', 'l', 'mite', 'cociente', 'incremental', 'incremento', 'h', 'tiende', 'cero', 'f', 'x', 'lim', 'h', 'f', 'x', 'h', 'f', 'x', 'h', 'geométricamente', 'valor', 'representa', 'pendiente', 'recta', 'tangente', 'curva', 'f', 'punto', 'x', 'f', 'x', 'derivada', 'positiva', 'función', 'crece', 'ese', 'punto', 'negativa', 'decrece', 'cero', 'punto', 'máximo', 'm', 'nimo', 'punto', 'inflexión', 'interpretación', 'f', 'sica', 'derivada', 'igualmente', 'poderosa', 'f', 't', 'representa', 'posición', 'objeto', 'instante', 't', 'entonces', 'f', 't', 'velocidad', 'instantánea', 'f', 't', 'segunda', 'derivada', 'aceleración', 'relación', 'posición', 'velocidad', 'aceleración', 'base', 'toda', 'mecánica', 'clásica', 'motivación', 'original', 'newton', 'desarrollar', 'cálculo', 'reglas', 'derivación', 'existen', 'varias', 'reglas', 'calcular', 'derivadas', 'recurrir', 'vez', 'definición', 'l', 'mite', 'importantes', 'encuentran', 'regla', 'potencia', 'establece', 'derivada', 'x', 'n', 'n', 'x', 'n', 'regla', 'producto', 'dice', 'derivada', 'f', 'g', 'f', 'g', 'f', 'g', 'regla', 'cociente', 'regla', 'cadena', 'quizás', 'utilizada', 'práctica', 'derivar', 'funciones', 'compuestas', 'regla', 'cadena', 'afirma', 'f', 'g', 'x', 'entonces', 'dy', 'dx', 'f', 'g', 'x', 'g', 'x', 'resultado', 'enorme', 'aplicación', 'ciencias', 'e', 'ingenier', 'variables', 'suelen', 'depender', 'unas', 'otras', 'través', 'relaciones', 'compuestas', 'dominar', 'estas', 'reglas', 'convierte', 'derivación', 'procedimiento', 'casi', 'mecánico', 'libera', 'atención', 'matemático', 'concentrarse', 'interpretación', 'resultados', 'aplicaciones', 'cálculo', 'diferencial', 'aplicaciones', 'cálculo', 'diferencial', 'prácticamente', 'ilimitadas', 'optimización', 'encontrar', 'valores', 'máximos', 'm', 'nimos', 'funciones', 'esencial', 'econom', 'ingenier', 'log', 'stica', 'diseño', 'empresa', 'derivadas', 'determinar', 'producción', 'maximiza', 'beneficios', 'minimiza', 'costos', 'f', 'sica', 'cálculo', 'diferencial', 'describe', 'comportamiento', 'dinámicos', 'mediante', 'ecuaciones', 'diferenciales', 'leyes', 'movimiento', 'newton', 'ecuaciones', 'maxwell', 'electromagnetismo', ' ...
#
#  Tokens Matematicas2
#  ['estad', 'stica', 'descriptiva', 'fundamentos', 'métodos', 'introducción', 'estad', 'stica', 'descriptiva', 'estad', 'stica', 'descriptiva', 'rama', 'estad', 'stica', 'dedicada', 'recopilar', 'organizar', 'resumir', 'presentar', 'datos', 'informativa', 'diferencia', 'estad', 'stica', 'inferencial', 'busca', 'generalizar', 'conclusiones', 'toda', 'población', 'partir', 'muestra', 'estad', 'stica', 'descriptiva', 'limita', 'describir', 'datos', 'observado', 'herramientas', 'transformar', 'grandes', 'volúmenes', 'información', 'medidas', 'concretas', 'visualizaciones', 'comprensibles', 'vivimos', 'era', 'datos', 'masivos', 'sensores', 'redes', 'sociales', 'salud', 'transacciones', 'financieras', 'generan', 'miles', 'millones', 'registros', 'd', 'herramientas', 'estad', 'stica', 'descriptiva', 'esa', 'información', 'ininteligible', 'gracias', 'ella', 'podemos', 'resumir', 'pocas', 'cifras', 'caracter', 'sticas', 'esenciales', 'datos', 'comunicar', 'hallazgos', 'clara', 'objetiva', 'medidas', 'tendencia', 'central', 'medidas', 'tendencia', 'central', 'buscan', 'identificar', 'valor', 'representativo', 'alrededor', 'cual', 'agrupan', 'datos', 'tres', 'comunes', 'media', 'aritmética', 'mediana', 'moda', 'media', 'promedio', 'obtiene', 'sumando', 'valores', 'dividiendo', 'número', 'observaciones', 'sensible', 'valores', 'extremos', 'outliers', 'distorsionar', 'interpretación', 'distribuciones', 'asimétricas', 'mediana', 'valor', 'ocupa', 'posición', 'central', 'datos', 'están', 'ordenados', 'número', 'observaciones', 'par', 'toma', 'promedio', 'dos', 'valores', 'centrales', 'mediana', 'robusta', 'frente', 'valores', 'extremos', 'resulta', 'representativa', 'media', 'distribuciones', 'colas', 'largas', 'ingresos', 'económicos', 'moda', 'valor', 'aparece', 'frecuencia', 'existir', 'distribuciones', 'bimodales', 'multimodales', 'medidas', 'dispersión', 'conocer', 'valor', 'central', 'datos', 'suficiente', 'fundamental', 'saber', 'qué', 'tan', 'dispersos', 'están', 'datos', 'alrededor', 'ese', 'centro', 'principales', 'medidas', 'dispersión', 'rango', 'varianza', 'desviación', 'estándar', 'coeficiente', 'variación', 'rango', 'diferencia', 'valor', 'máximo', 'm', 'nimo', 'simple', 'calcular', 'sensible', 'valores', 'extremos', 'varianza', 'mide', 'promedio', 'cuadrados', 'diferencias', 'observación', 'media', 'ra', 'z', 'cuadrada', 'desviación', 'estándar', 'ventaja', 'estar', 'expresada', 'unidades', 'datos', 'originales', 'facilita', 'interpretación', 'coeficiente', 'variación', 'razón', 'desviación', 'estándar', 'media', 'multiplicada', 'especialmente', 'útil', 'comparar', 'dispersión', 'relativa', 'datos', 'unidades', 'magnitudes', 'distribuciones', 'frecuencia', 'visualización', 'tabla', 'frecuencias', 'organiza', 'datos', 'clases', 'intervalos', 'muestra', 'cuántas', 'observaciones', 'caen', 'partir', 'tabla', 'construyen', 'histogramas', 'representaciones', 'gráficas', 'distribución', 'datos', 'histograma', 'revela', 'caracter', 'sticas', 'importantes', 'simétrico', 'varias', 'colas', 'pronunciadas', 'existe', 'multimodalidad', 'etc', 'otras', 'representaciones', 'visuales', 'habituales', 'estad', 'stica', 'descriptiva', 'diagrama', 'caja', 'boxplot', 'resume', 'solo', 'gráfico', 'mediana', 'cuartiles', 'valores', 'at', 'picos', 'diagrama', 'dispersión', 'explorar', 'relaciones', 'dos', 'variables', 'gráfico', 'sectores', 'adecuado', 'mostrar', 'proporciones', 'categor', 'as', 'variable', 'cualitativa', 'elección', 'gráfico', 'adecuado', 'depende', 'variable', 'mensaje', 'desea', 'comunicar', 'correlación', 'covarianza', 'trabaja', 'dos', 'variables', 'numéricas', 'interesa', 'saber', 'existe', 'relación', 'lineal', 'covarianza', 'mide', 'qué', 'dirección', 'var', 'an', 'conjuntamente', 'dos', 'variables', 'positiva', 'tienden', 'crecer', 'juntas', 'negativa', 'crece', 'otra', 'decrece', 'embargo', 'covarianza', 'depende', 'unidades', 'medida', 'dificulta', 'comparación', 'pares', 'variables', 'coeficiente', 'correlación', 'pearso ...
#
#  Tokens Biologia1
#  ['ecosistemas', 'estructura', 'función', 'biodiversidad', 'qué', 'ecosistema', 'ecosistema', 'sistema', 'complejo', 'formado', 'organismos', 'habitan', 'área', 'determinada', 'biótica', 'factores', 'f', 'sicos', 'qu', 'micos', 'entorno', 'componentes', 'abióticos', 'esos', 'organismos', 'interactúan', 'término', 'acuñado', 'ecólogo', 'británico', 'arthur', 'tansley', 'representa', 'cambio', 'conceptual', 'fundamental', 'lugar', 'estudiar', 'organismos', 'aislada', 'ecolog', 'ecosistemas', 'considera', 'relación', 'ambiente', 's', 'ecosistemas', 'tener', 'escalas', 'diferentes', 'pequeño', 'charco', 'agua', 'océano', 'jard', 'n', 'urbano', 'selva', 'amazónica', 'define', 'ecosistema', 'tamaño', 'existencia', 'flujos', 'energ', 'ciclos', 'conectan', 'componentes', 'ecosistemas', 'planeta', 'conectados', 's', 'atmósfera', 'océanos', 'ciclos', 'biogeoqu', 'micos', 'forman', 'biosfera', 'capa', 'viva', 'tierra', 'componentes', 'bióticos', 'abióticos', 'componentes', 'bióticos', 'ecosistema', 'clasifican', 'según', 'papel', 'funcional', 'productores', 'autótrofos', 'principalmente', 'plantas', 'algas', 'capturan', 'energ', 'solar', 'convierten', 'orgánica', 'fotos', 'ntesis', 'consumidores', 'heterótrofos', 'obtienen', 'energ', 'comiendo', 'organismos', 'herb', 'voros', 'comen', 'plantas', 'consumidores', 'primarios', 'carn', 'voros', 'comen', 'herb', 'voros', 'consumidores', 'secundarios', 'as', 'sucesivamente', 'descomponedores', 'bacterias', 'hongos', 'degradan', 'orgánica', 'muerta', 'liberan', 'nutrientes', 'suelo', 'agua', 'factores', 'abióticos', 'incluyen', 'temperatura', 'luz', 'solar', 'disponibilidad', 'agua', 'suelo', 'ph', 'concentración', 'nutrientes', 'estos', 'factores', 'determinan', 'qué', 'organismos', 'vivir', 'lugar', 'condicionan', 'productividad', 'ecosistema', 'ejemplo', 'desiertos', 'poca', 'precipitación', 'limita', 'vegetación', 'cantidad', 'variedad', 'animales', 'sostenerse', 'selvas', 'tropicales', 'alta', 'temperatura', 'abundante', 'lluvia', 'año', 'ecosistemas', 'mayor', 'productividad', 'biodiversidad', 'planeta', 'flujos', 'energ', 'redes', 'tróficas', 'energ', 'entra', 'ecosistemas', 'principalmente', 'fotos', 'ntesis', 'transforma', 'energ', 'lum', 'nica', 'energ', 'qu', 'mica', 'almacenada', 'moléculas', 'orgánicas', 'medida', 'esa', 'energ', 'pasa', 'nivel', 'trófico', 'siguiente', 'productores', 'herb', 'voros', 'herb', 'voros', 'carn', 'voros', 'pierde', 'calor', 'eficiencia', 'ecológica', 'media', 'niveles', 'tróficos', 'aproximadamente', 'explica', 'qué', 'cadenas', 'alimentarias', 'raramente', 'cuatro', 'cinco', 'eslabones', 'cadenas', 'alimentarias', 'simplificaciones', 'realidad', 'ecosistemas', 'reales', 'relaciones', 'alimentación', 'forman', 'redes', 'tróficas', 'complejas', 'organismo', 'alimentarse', 'múltiples', 'presas', 'vez', 'consumido', 'múltiples', 'depredadores', 'complejidad', 'otorga', 'resiliencia', 'ecosistema', 'si', 'desaparece', 'ocupar', 'lugar', 'funcional', 'clave', 'keystone', 'species', 'aquellas', 'pesar', 'relativamente', 'poco', 'abundantes', 'impacto', 'desproporcionadamente', 'grande', 'estructura', 'ecosistema', 'ciclos', 'biogeoqu', 'micos', 'diferencia', 'energ', 'fluye', 'sola', 'dirección', 'ecosistema', 'recicla', 'ciclos', 'biogeoqu', 'micos', 'describen', 'cómo', 'elementos', 'qu', 'micos', 'carbono', 'nitrógeno', 'fósforo', 'agua', 'circulan', 'organismos', 'compartimentos', 'abióticos', 'ciclo', 'carbono', 'fundamental', 'entender', 'cambio', 'climático', 'carbono', 'fija', 'fotos', 'ntesis', 'circula', 'redes', 'tróficas', 'liberado', 'respiración', 'descomposición', 'acumula', 'reservorios', 'océanos', 'suelos', 'combustibles', 'fósiles', 'ciclo', 'nitrógeno', 'esencial', 'nitrógeno', 'componente', 'básico', 'prote', 'nas', 'ácidos', 'nucleicos', 'atmósfera', 'nitrógeno', 'mayor', 'organismos', 'utilizarlo', 'directamente', 'dependen', 'bacterias', 'fijadoras', 'nitrógeno', 'convierten', 'asimilables', 'actividades', 'humanas', 'uso', 'masivo',  ...
#
#  Tokens Biologia2
#  ['célula', 'unidad', 'fundamental', 'historia', 'descubrimiento', 'celular', 'historia', 'biolog', 'celular', 'comienza', 'siglo', 'xvii', 'invención', 'microscopio', 'cient', 'fico', 'inglés', 'robert', 'hooke', 'observó', 'lámina', 'corcho', 'bajo', 'microscopio', 'rudimentario', 'notó', 'estaba', 'formada', 'pequeñas', 'cámaras', 'denominó', 'células', 'lat', 'n', 'cellula', 'habitáculo', 'pequeño', 'hooke', 'observó', 'células', 'muertas', 'vac', 'as', 'contenido', 'holandés', 'antonie', 'van', 'leeuwenhoek', 'poco', 'después', 'describió', 'primera', '
 'ciclo', 'celular', 'células', 'eucariotas', 'ciclo', 'divide', 'interfase', 'per', 'odo', 'crecimiento', 'duplicación', 'adn', 'fase', 'mitótica', 'célula', 'divide', 'interfase', 'subdivide', 'g', 'crecimiento', 'celular', 's', 's', 'ntesis', 'adn', 'g', 'preparación', 'división', 'fase', 's', 'adn', 'replica', 'extraordinaria', 'fidelidad', 'gracias', 'complejo', 'sistema', 'enzimas', 'prote', 'nas', 'correctoras', 'mitosis', 'proceso', 'división', 'núcleo', 'gen ...
#
#  Tokens Geografia1
#  ['cambio', 'climático', 'causas', 'efectos', 'perspectivas', 'geográficas', 'climático', 'terrestre', 'clima', 'tierra', 'resultado', 'complejas', 'interacciones', 'atmósfera', 'hidrosfera', 'criosfera', 'litosfera', 'biosfera', 'energ', 'solar', 'motor', 'sol', 'emite', 'radiación', 'atraviesa', 'atmósfera', 'calienta', 'terrestre', 'esa', 'energ', 'reemitida', 'radiación', 'infrarroja', 'gases', 'efecto', 'invernadero', 'vapor', 'agua', 'dióxido', 'carbono', 'metano', 'óxido', 'nitroso', 'absorben', 'redirigen', 'manteniendo', 'temperatura', 'media', 'global', 'aproximadamente', 'c', 'efecto', 'invernadero', 'natural', 'temperatura', 'media', 'tierra', 'unos', 'c', 'har', 'imposible', 'vida', 'tal', 'conocemos', 'problema', 'surge', 'actividades', 'humanas', 'aumentan', 'concentración', 'gases', 'efecto', 'invernadero', 'atmósfera', 'intensificando', 'efecto', 'allá', 'l', 'mites', 'históricos', 'provocando', 'calentamiento', 'adicional', 'conocido', 'cambio', 'climático', 'antropogénico', 'causas', 'cambio', 'climático', 'actual', 'principal', 'causa', 'cambio', 'climático', 'actual', 'quema', 'combustibles', 'fósiles', 'carbón', 'petróleo', 'gas', 'natural', 'producir', 'energ', 'eléctrica', 'mover', 'veh', 'culos', 'e', 'impulsar', 'industria', 'libera', 'dióxido', 'carbono', 'co', 'almacenado', 'millones', 'años', 'subsuelo', 'revolución', 'industrial', 'concentración', 'co', 'atmósfera', 'ha', 'pasado', 'partes', 'millón', 'partes', 'millón', 'nivel', 'alto', 'menos', 'años', 'según', 'registros', 'núcleos', 'hielo', 'polar', 'fuentes', 'importantes', 'emisiones', 'deforestación', 'reduce', 'capacidad', 'bosques', 'absorber', 'co', 'ganader', 'intensiva', 'genera', 'grandes', 'cantidades', 'metano', 'agricultura', 'produce', 'metano', 'óxido', 'nitroso', 'cultivo', 'arroz', 'uso', 'fertilizantes', 'nitrogenados', 'urbanización', 'acelerada', 'crecimiento', 'demanda', 'energética', 'global', 'hacen', 'pesar', 'esfuerzos', 'transitar', 'energ', 'as', 'renovables', 'emisiones', 'totales', 'sigan', 'aumentando', 'año', 'tras', 'año', 'efectos', 'f', 'sicos', 'calentamiento', 'global', 'está', 'alterando', 'f', 'sicos', 'manera', 'profunda', 'muchos', 'casos', 'irreversible', 'deshielo', 'glaciares', 'capas', 'hielo', 'polares', 'está', 'elevando', 'nivel', 'mar', 'amenazando', 'costas', 'deltas', 'e', 'islas', 'baja', 'altitud', 'estima', 'n
os', 'instantáneamente', 'pulverizarlos', 'obteniendo', 'polvo', 'funde', 'boca', 'sensación', 'fresca', 'explosiva', 'popularizada', 'ferran', 'adrià', 'hoy', 'utiliza', 'restaurantes', 'buscan', 'sorprender', 'comensal', 'juegos', 'espumas', 'aires', 'espumas', 'aires', 'consisten', 'atrapar', 'burbujas', 'aire', 'matriz', 'l', 'quida', 'semi', 'sólida', 'creando', 'ultraligeras', 'aportan', 'casi', 'presencia', 'f', 'sica', 'ferran', 'adrià', 'pionero', 'introducir', 'espumas', 'cocina', 'vanguardia', 'mediados', 'años', 'noventa', 'comenzando', 'espuma', 'jud', 'as', 'blancas', 'trufa', 'convirtió', 'platos', 'fotografiados', 'historia', 'gastronom', 'aires', 'etéreos', 'espumas', 'obtienen', 'añadiendo', 'lecitina', 'soja', 'l', 'quido', 'saborizado', 'batiéndolo', 'batidora', 'mano', 'superficie', 'burbujas', 'formadas', 'tan', 'ligeras', 'depositarse', 'plato', 'si', 'fuera', 'niebla', 'nieve', 'aire', 'mar', 'obtenido', 'agua', 'mar', 'filtrada', 'evocar', ...
#
#  Tokens Cocina2
#  ['gastronom', 'as', 'viaje', 'culinario', 'cinco', 'continentes', 'cocina', 'espejo', 'cultura', 'gastronom', 'pueblo', 'mucho', 'conjunto', 'recetas', 'reflejo', 'historia', 'geograf', 'creencias', 'religiosas', 'intercambios', 'comerciales', 'identidad', 'colectiva', 'ingredientes', 'usa', 'cultura', 'revelan', 'ecosistemas', 'habita', 'aplica', 'muestran', 'tecnolog', 'disponible', 'distintas', 'épocas', 'especias', 'condimentos', 'prefiere', 'cuentan', 'historias', 'rutas', 'comerciales', 'encuentros', 'civilizaciones', 'comer', 'sentido', 'acto', 'profundamente', 'cultural', 'globalización', 'ha', 'transformado', 'patrones', 'alimentarios', 'hoy', 'posible', 'comer', 'sushi', 'buenos', 'aires', 'tacos', 'tokio', 'curry', 'berl', 'n', 'intercambio', 'dos', 'caras', 'lado', 'enriquece', 'repertorio', 'culinario', 'global', 'permite', 'diálogo', 'culturas', 'amenaza', 'diversidad', 'gastronómica', 'imponer', 'modelos', 'homogeneizadores', 'basados', 'comida', 'rápida', 'productos', 'ultraprocesados', 'preservar', 'cocinas', 'preservar', 'diversidad', 'cultural', 'humanidad', 'cocinas', 'asia', 'tradición', 'sofisticación', 'asia', 'alberga', 'algunas', 'tradiciones', 'culinarias', 'antiguas', 'complejas', 'cocina', 'china', 'tres', 'mil', 'años', 'historia', 'documentada', 'quizás', 'influyente', 'escala', 'global', 'organiza', 'grandes', 'escuelas', 'regionales', 'cantonesa', 'famosa', 'delicadeza', 'wok', 'sichuan', 'conocida', 'picante', 'intenso', 'pimiento', 'rojo', 'shangai', 'dulces', 'famosos', 'xiaolongbao', 'bollos', 'sopa', 'cocina', 'japonesa', 'ha', 'elevado', 'precisión', 'respeto', 'ingrediente', 'filosof', 'vida', 'washoku', 'cocina', 'japonesa', 'inscrito', 'lista', 'patrimonio', 'inmaterial', 'unesco', 'principios', 'incluyen', 'ingredientes', 'frescos', 'temporada', 'equilibrio', 'colores', 'presentación', 'cuidadosa', 'convierte', 'plato', 'obra', 'arte', 'visual', 'umami', 'quinto', 'básico', 'identificado', 'cient', 'fico', 'japonés', 'kikunae', 'ikeda', 'omnipresente', 'cocina', 'japonesa', 'dashi', 'caldo', 'kombu', 'bonito', 'seco', 'soja', 'miso', 'cocinas', 'américa', 'latina', 'mestizaje', 'e', 'identidad', 'gastronom', 'as', 'latinoamericanas', 'resultado', 'encuentro', 'extraordinario', 'tradiciones', 'culinarias', 'ind', 'genas', 'milenarias', 'cocina', 'europea', 'tra', 'da', 'colonizadores', 'aportaciones', 'comunidades', 'africanas', 'asiáticas', 'llegaron', 'posteriormente', 'méxico', 'perú', 'brasil', 'poseen', 'tres', 'cocinas', 'reconocidas', 'valoradas', 'actualmente', 'mexicana', 'reconocida', 'unesco', 'patrimonio', 'cultural', 'inmaterial', 'humanidad', 'cocina', 'peruana', 'caso', 'excepcional', 'diversidad', 'e', 'innovación', 'combina', 'ingredientes', 'selva', 'amazónica', 'andes', 'litoral', 'pac', 'fico', 'influencias', 'japonesas', 'comunidad', 'nikkei', 'chinas', 'cocina', 'chifa', 'africanas', 'ceviche', 'preparado', 'pescado', 'fresco', 'marinado', 'jugo', 'limón', 'aj', 'cebolla', 'morada', 'ha', 'convertido', 's', 'mbolo', 'identidad', 'nacional', 'platos', 'imitados', 'lima', 'ha', 'establecido', 'últimas', 'décadas', 'capitales', 'gastronómicas', 'mundiales', 'cocinas', 'mediterráneas', 'salud', 'convivencia', 'dieta', 'mediterránea', 'considerada', 'nutricionistas', 'patrones', 'alimentarios', 'saludables', 'inscrita', 'lista', 'patrimonio', 'inmaterial', 'unesco', 'valor', 'nutricional', 'estilo', 'vida', 'representa', 'convivencia', 'mesa', 'mercados', 'locales', 'respeto', 'estaciones', 'celebración', 'comunitaria', 'caracteriza', 'abundante', 'aceite', 'oliva', 'verduras', 'legumbres', 'cereales', 'integrales', 'pescado', 'frutos', 'secos', 'consumo', 'moderado', 'carne', 'roja', 'vino', 'dentro', 'paraguas', 'mediterráneo', 'coexisten', 'cocinas', 'distintas', 'italiana', 'pasta', 'risotto', 'pizza', 'gelato', 'quizás', 'conocida', 'española', 'aporta', 'paella', 'gazpacho', 'embutidos', 'ibéricos', 'rica', 'tradición', 'tapas', 'griega', 'ofrece', 'gyros', 'souv ...

# %%
# tokens totales del corpus
print(f"Cantidad de tokens Turismo1 : {contar_tokens(corpus_turismo1_tokenizado)}")
print(f"Cantidad de tokens Tursimo2 : {contar_tokens(corpus_turismo2_tokenizado)}")

print(f"\nCantidad de tokens Matematicas1 : {contar_tokens(corpus_mate1_tokenizado)}")
print(f"Cantidad de tokens Matematicas2 : {contar_tokens(corpus_mate2_tokenizado)}")

print(f"\nCantidad de tokens Biologia1: {contar_tokens(corpus_bio1_tokenizado)}")
print(f"Cantidad de tokens Biologia2: {contar_tokens(corpus_bio2_tokenizado)}")

print(f"\nCantidad de tokens Geografia1: {contar_tokens(corpus_geo1_tokenizado)}")
print(f"Cantidad de tokens Geografia2: {contar_tokens(corpus_geo2_tokenizado)}")

print(f"\nCantidad de tokens Cocina1: {contar_tokens(corpus_cocina1_tokenizado)}")
print(f"Cantidad de tokens Cocina2: {contar_tokens(corpus_cocina2_tokenizado)}")
# Out:
# Cantidad de tokens Turismo1 : 443
# Cantidad de tokens Tursimo2 : 439
#
# Cantidad de tokens Matematicas1 : 410
# Cantidad de tokens Matematicas2 : 380
#
# Cantidad de tokens Biologia1: 435
# Cantidad de tokens Biologia2: 477
#
# Cantidad de tokens Geografia1: 454
# Cantidad de tokens Geografia2: 437
#
# Cantidad de tokens Cocina1: 485
# Cantidad de tokens Cocina2: 468

# %% [markdown]
# Finalmente lematizamos

# %%
turismo1_lematizado_tokenizado = lematizador_tokenizado(corpus_turismo1_tokenizado)
turismo2_lematizado_tokenizado = lematizador_tokenizado(corpus_turismo2_tokenizado)

mate1_lematizado_tokenizado = lematizador_tokenizado(corpus_mate1_tokenizado)
mate2_lematizado_tokenizado = lematizador_tokenizado(corpus_mate2_tokenizado)

bio1_lematizado_tokenizado = lematizador_tokenizado(corpus_bio1_tokenizado)
bio2_lematizado_tokenizado = lematizador_tokenizado(corpus_bio2_tokenizado)

geo1_lematizado_tokenizado = lematizador_tokenizado(corpus_geo1_tokenizado)
geo2_lematizado_tokenizado = lematizador_tokenizado(corpus_geo2_tokenizado)

cocina1_lematizado_tokenizado = lematizador_tokenizado(corpus_cocina1_tokenizado)
cocina2_lematizado_tokenizado = lematizador_tokenizado(corpus_cocina2_tokenizado)

# %%
# lematizadores
print(f"Cantidad de palabras Turismo1 : {contar_tokens(turismo1_lematizado_tokenizado)}")
print(f"Cantidad de palabras Tursimo2 : {contar_tokens(turismo2_lematizado_tokenizado)}")

print(f"\nCantidad de palabras Matematicas1 : {contar_tokens(mate1_lematizado_tokenizado)}")
print(f"Cantidad de palabras Matematicas2 : {contar_tokens(mate2_lematizado_tokenizado)}")

print(f"\nCantidad de palabras Biologia1: {contar_tokens(bio1_lematizado_tokenizado)}")
print(f"Cantidad de palabras Biologia2: {contar_tokens(bio2_lematizado_tokenizado)}")

print(f"\nCantidad de palabras Geografia1: {contar_tokens(geo1_lematizado_tokenizado)}")
print(f"Cantidad de palabras Geografia2: {contar_tokens(geo2_lematizado_tokenizado)}")

print(f"\nCantidad de palabras Cocina1: {contar_tokens(cocina1_lematizado_tokenizado)}")
print(f"Cantidad de palabras Cocina2: {contar_tokens(cocina2_lematizado_tokenizado)}")
# Out:
# Cantidad de palabras Turismo1 : 443
# Cantidad de palabras Tursimo2 : 439
#
# Cantidad de palabras Matematicas1 : 410
# Cantidad de palabras Matematicas2 : 380
#
# Cantidad de palabras Biologia1: 435
# Cantidad de palabras Biologia2: 477
#
# Cantidad de palabras Geografia1: 454
# Cantidad de palabras Geografia2: 437
#
# Cantidad de palabras Cocina1: 485
# Cantidad de palabras Cocina2: 468

# %% [markdown]
# ## BOW y Modelo

# %% [markdown]
# ### Bag of Words

# %% [markdown]
# ### Modelo

# %% [markdown]
# ### Crear Documentos

# %% [markdown]
# ### Métricas
